# %%
# Import dependencies and setup

import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as matplotlib

# %%
# Read .csv and store as DataFrame

rental_vacancy_1_path = "Resources/capital_city_rental_vacancy_rates.csv"
rental_vacancy_1_df = pd.read_csv(rental_vacancy_1_path)

rental_vacancy_2_path = "Resources/residential_property_rental_vacancy_sqm.csv"
rental_vacancy_2_df = pd.read_csv(rental_vacancy_2_path)

# %%
# Preview 1_df

rental_vacancy_1_df
# Out:
#         City Rental Change - House (%) Rental Change - Unit (%)
# 0     Sydney                    11.50%                    6.70%
# 1  Melbourne                     4.70%                   -2.60%
# 2   Brisbane                     8.50%                    4.20%
# 3   Adelaide                    10.40%                    2.70%
# 4      Perth                    11.60%                    5.00%
# 5     Hobart                    12.10%                   -0.30%
# 6     Darwin                    10.90%                   24.70%
# 7   Canberra                    15.50%                   10.00%

# %%
# Preview 2_df

rental_vacancy_2_df
# Out:
#         City  Feb 2021 Vacancies Feb 2021 Vacancy Rate  Jan 2022 Vacancies  \
# 0     Sydney               24820                  3.3%               16357
# 1  Melbourne               27804                  4.5%               17112
# 2   Brisbane                5310                  1.5%                3878
# 3      Perth                1858                  1.0%                1285
# 4   Adelaide                1466                  0.7%                 819
# 5   Canberra                 535                  0.8%                 489
# 6     Darwin                 230                  0.7%                 306
# 7     Hobart                 194                  0.6%                  86
# 8   National               71551                  2.0%               47977
#
#   Jan 2022 Vacancy Rate  Feb 2022 Vacancies Feb 2022 Vacancy Rate
# 0                  2.1%               15145                  2.0%
# 1                  2.7%               14777                  2.3%
# ...

# %%
# Plot 'rental_vacancy_1_df'

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

plotdata_1 = pd.DataFrame({
    "House":[11.5, 4.70, 8.50, 10.40, 11.60, 12.10, 10.90, 15.50],
    "Unit":[6.70, -2.60, 4.20, 2.70, 5.00, -0.30, 24.70, 10.00],
    
    }, 
    index=["Sydney", "Melbourne", "Brisbane", "Adelaide", "Perth", "Hobart", "Darwin", "Canberra"]
)

plotdata_1.plot(figsize=(15,5), kind="bar", alpha=1, rot=0)
plt.title("12-month change in weekly residential rental prices, February 2021 – February 2022",  fontdict = font_1)
plt.xlabel("City", fontdict = font_2)
plt.ylabel("Percent change",  fontdict = font_2)

# Grid
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', 
                       alpha=0.1, linestyle='--', linewidth=1)

# Aesthetics
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Show/save
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/australian-rental-vacancy-rates/Images/rental_change_price.png", 
            transparent=False, dpi=300)
plt.show()

# %%
# Preview 2_df

rental_vacancy_2_df
# Out:
#         City  Feb 2021 Vacancies Feb 2021 Vacancy Rate  Jan 2022 Vacancies  \
# 0     Sydney               24820                  3.3%               16357
# 1  Melbourne               27804                  4.5%               17112
# 2   Brisbane                5310                  1.5%                3878
# 3      Perth                1858                  1.0%                1285
# 4   Adelaide                1466                  0.7%                 819
# 5   Canberra                 535                  0.8%                 489
# 6     Darwin                 230                  0.7%                 306
# 7     Hobart                 194                  0.6%                  86
# 8   National               71551                  2.0%               47977
#
#   Jan 2022 Vacancy Rate  Feb 2022 Vacancies Feb 2022 Vacancy Rate
# 0                  2.1%               15145                  2.0%
# 1                  2.7%               14777                  2.3%
# ...

# %%
# Plot 'rental_vacancy_2_df' - Vacancies #

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

plotdata_1 = pd.DataFrame({
    "February 2021 Vacancies":[24820, 27804, 5310, 1858, 1466, 535, 230, 194],
    "January 2022 Vacancies":[16357, 17112, 3878, 1285, 819, 489, 306, 86],
    "February 2022 Vacancies":[15145, 14777, 3328, 1390, 776, 378, 234, 99]
    
    }, 
    index=["Sydney", "Melbourne", "Brisbane", "Perth", "Adelaide", "Canberra", "Darwin", "Hobart"]
)

plotdata_1.plot(figsize=(15,5), kind="bar", alpha=1, rot=0)
plt.title("Residential property rental vacancy rates, February 2021 – February 2022",  fontdict = font_1)
plt.xlabel("City", fontdict = font_2)
plt.ylabel("Vacancies",  fontdict = font_2)

# Grid
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', 
                       alpha=0.1, linestyle='--', linewidth=1)

# Aesthetics
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Show/save
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/australian-rental-vacancy-rates/Images/rental_vacancies_city.png", 
            transparent=False, dpi=300)
plt.show()

# %%
# Plot 'rental_vacancy_2_df' - Vacancies # (National)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

plotdata_1 = pd.DataFrame({
    "February 2021 Vacancies":[71551],
    "January 2022 Vacancies":[47977],
    "February 2022 Vacancies":[43844]
    
    }, 
    index=["National"]
)

plotdata_1.plot(figsize=(15,5), kind="bar", width=0.25, alpha=1, rot=0)
plt.title("Residential property rental vacancy rates (National), February 2021 – February 2022",  fontdict = font_1)
plt.xlabel("", fontdict = font_2)
plt.ylabel("Vacancies",  fontdict = font_2)

# Grid
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', 
                       alpha=0.1, linestyle='--', linewidth=1)

# Aesthetics
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Show/save
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/australian-rental-vacancy-rates/Images/rental_vacancies_national.png", 
            transparent=False, dpi=300)
plt.show()

# %%
# Plot 'rental_vacancy_2_df' - Vacancies Rate (state)

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

plotdata_1 = pd.DataFrame({
    "February 2021 Vacancies":[3.3, 4.5, 1.5, 1.0, 0.7, 0.8, 0.7, 0.6, 2.0],
    "January 2022 Vacancies":[2.1, 2.7, 1.1, 0.6, 0.4, 0.7, 0.9, 0.3, 1.3],
    "February 2022 Vacancies":[2.0, 2.3, 0.9, 0.6, 0.4, 0.5, 0.7, 0.3, 1.2]
    
    }, 
    index=["Sydney", "Melbourne", "Brisbane", "Perth", "Adelaide", "Canberra", "Darwin", "Hobart", "National"]
)

plotdata_1.plot(figsize=(15,5), kind="bar", width=0.5, alpha=1, rot=0)
plt.title("Residential property rental vacancy rates, percent, February 2021 – February 2022",  fontdict = font_1)
plt.xlabel("City", fontdict = font_2)
plt.ylabel("Vacancy Rate (%)",  fontdict = font_2)

# Grid
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', 
                       alpha=0.1, linestyle='--', linewidth=1)

# Aesthetics
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Show/save
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/australian-rental-vacancy-rates/Images/rental_vacancies_rate.png", 
            transparent=False, dpi=300)
plt.show()
